# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 767

# %%
# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):

    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
                          
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | atasu
# Processing Record 5 of Set 1 | stoughton
# Processing Record 6 of Set 1 | manta
# Processing Record 7 of Set 1 | saskylakh
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | iqaluit
# Processing Record 11 of Set 1 | kruisfontein
# Processing Record 12 of Set 1 | saint-philippe
# Processing Record 13 of Set 1 | santiago del estero
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | yar-sale
# Processing Record 17 of Set 1 | tura
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | khatanga
# Processing Record 20 of Set 1 | westport
# Processing Record 21 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | kattivakkam
# Processing Record 27 of Set 1 | kahului
# Processing Record 28 of Set 1 | kodiak
# Processing Record 29 of Set 1 | dunedin
# Processing Record 30 of Set 1 | garowe
# Processing Record 31 of Set 1 | faanui
# Processing Record 32 of Set 1 | flinders
# Processing Record 33 of Set 1 | kutum
# Processing Record 34 of Set 1 | rayagada
# Processing Record 35 of Set 1 | dudinka
# Processing Record 36 of Set 1 | hami
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | mahebourg
# Processing Record 39 of Set 1 | benjamin constant
# Processing Record 40 of Set 1 | norman wells
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | buchanan
# Processing Record 44 of Set 1 | ponta do sol
# Processing Record 45 of Set 1 | narsaq
# Processing Record 46 of Set 1 | baymak
# Processing Record 47 of Set 1 | khvoynaya
# Processing Record 48 of Set 1 | kieta
# Processing Record 49 of Set 1 | mormugao
# Processing Record 50 of Set 1 | lazaro cardenas
# Processing Record 1 of Set 2 | dupnica
# City not found. Skipping...
# Processing Record 2 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | krasnyy chikoy
# Processing Record 5 of Set 2 | cidreira
# Processing Record 6 of Set 2 | san cristobal
# Processing Record 7 of Set 2 | tiarei
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | east london
# Processing Record 10 of Set 2 | vinkovci
# Processing Record 11 of Set 2 | wajid
# Processing Record 12 of Set 2 | bethel
# Processing Record 13 of Set 2 | dikson
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | bandarbeyla
# Processing Record 16 of Set 2 | barrow
# Processing Record 17 of Set 2 | kandrian
# Processing Record 18 of Set 2 | marsaxlokk
# Processing Record 19 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 2 | castro
# Processing Record 21 of Set 2 | torbay
# Processing Record 22 of Set 2 | new norfolk
# Processing Record 23 of Set 2 | ahuimanu
# Processing Record 24 of Set 2 | upernavik
# Processing Record 25 of Set 2 | vaini
# Processing Record 26 of Set 2 | kendari
# Processing Record 27 of Set 2 | tuktoyaktuk
# Processing Record 28 of Set 2 | san quintin
# Processing Record 29 of Set 2 | kushiro
# Processing Record 30 of Set 2 | san patricio
# Processing Record 31 of Set 2 | saint george
# Processing Record 32 of Set 2 | cherskiy
# Processing Record 33 of Set 2 | namibe
# Processing Record 34 of Set 2 | hobart
# Processing Record 35 of Set 2 | butaritari
# Processing Record 36 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 2 | aksu
# Processing Record 38 of Set 2 | ladybrand
# Processing Record 39 of Set 2 | mulege
# Processing Record 40 of Set 2 | rio grande
# Processing Record 41 of Set 2 | tawang
# Processing Record 42 of Set 2 | puerto narino
# Processing Record 43 of Set 2 | huilong
# Processing Record 44 of Set 2 | thompson
# Processing Record 45 of Set 2 | ahipara
# Processing Record 46 of Set 2 | san isidro
# Processing Record 47 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 2 | bambous virieux
# Processing Record 49 of Set 2 | carnarvon
# Processing Record 50 of Set 2 | roebourne
# Processing Record 1 of Set 3 | puro
# Processing Record 2 of Set 3 | pacific grove
# Processing Record 3 of Set 3 | wajima
# Processing Record 4 of Set 3 | vostok
# Processing Record 5 of Set 3 | bonavista
# Processing Record 6 of Set 3 | tiznit
# Processing Record 7 of Set 3 | hirara
# Processing Record 8 of Set 3 | souillac
# Processing Record 9 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 10 of Set 3 | neiafu
# Processing Record 11 of Set 3 | kawalu
# Processing Record 12 of Set 3 | punta arenas
# Processing Record 13 of Set 3 | gogrial
# Processing Record 14 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 3 | solnechnyy
# Processing Record 16 of Set 3 | ngunguru
# Processing Record 17 of Set 3 | tiksi
# Processing Record 18 of Set 3 | kavieng
# Processing Record 19 of Set 3 | hasaki
# Processing Record 20 of Set 3 | port lincoln
# Processing Record 21 of Set 3 | porto walter
# Processing Record 22 of Set 3 | doljo
# Processing Record 23 of Set 3 | yuzhnyy
# Processing Record 24 of Set 3 | pevek
# Processing Record 25 of Set 3 | arraial do cabo
# Processing Record 26 of Set 3 | fukue
# Processing Record 27 of Set 3 | jumla
# Processing Record 28 of Set 3 | coquimbo
# Processing Record 29 of Set 3 | seoul
# Processing Record 30 of Set 3 | paamiut
# Processing Record 31 of Set 3 | broome
# Processing Record 32 of Set 3 | adrar
# Processing Record 33 of Set 3 | pangoa
# Processing Record 34 of Set 3 | talnakh
# Processing Record 35 of Set 3 | buqayq
# City not found. Skipping...
# Processing Record 36 of Set 3 | trelew
# Processing Record 37 of Set 3 | klaksvik
# Processing Record 38 of Set 3 | katsuura
# Processing Record 39 of Set 3 | pisco
# Processing Record 40 of Set 3 | lorengau
# Processing Record 41 of Set 3 | makushino
# Processing Record 42 of Set 3 | puerto baquerizo moreno
# Processing Record 43 of Set 3 | pasni
# Processing Record 44 of Set 3 | abengourou
# Processing Record 45 of Set 3 | notodden
# Processing Record 46 of Set 3 | tome-acu
# City not found. Skipping...
# Processing Record 47 of Set 3 | kiunga
# Processing Record 48 of Set 3 | cabo san lucas
# Processing Record 49 of Set 3 | port alfred
# Processing Record 50 of Set 3 | hilton head island
# Processing Record 1 of Set 4 | slave lake
# Processing Record 2 of Set 4 | trairi
# Processing Record 3 of Set 4 | le port
# Processing Record 4 of Set 4 | agudos
# Processing Record 5 of Set 4 | campos
# Processing Record 6 of Set 4 | chuy
# Processing Record 7 of Set 4 | patacamaya
# Processing Record 8 of Set 4 | tazmalt
# Processing Record 9 of Set 4 | victoria
# Processing Record 10 of Set 4 | omsukchan
# Processing Record 11 of Set 4 | esperance
# Processing Record 12 of Set 4 | san jose
# Processing Record 13 of Set 4 | el dorado
# Processing Record 14 of Set 4 | korla
# Processing Record 15 of Set 4 | matagami
# Processing Record 16 of Set 4 | tasiilaq
# Processing Record 17 of Set 4 | alofi
# Processing Record 18 of Set 4 | poykovskiy
# Processing Record 19 of Set 4 | matara
# Processing Record 20 of Set 4 | avera
# Processing Record 21 of Set 4 | tambopata
# Processing Record 22 of Set 4 | clyde river
# Processing Record 23 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 4 | ribeira grande
# Processing Record 25 of Set 4 | emba
# Processing Record 26 of Set 4 | lompoc
# Processing Record 27 of Set 4 | kaitangata
# Processing Record 28 of Set 4 | alice springs
# Processing Record 29 of Set 4 | dingle
# Processing Record 30 of Set 4 | gnjilane
# Processing Record 31 of Set 4 | biloela
# Processing Record 32 of Set 4 | srednekolymsk
# Processing Record 33 of Set 4 | copiapo
# Processing Record 34 of Set 4 | chara
# Processing Record 35 of Set 4 | zhigansk
# Processing Record 36 of Set 4 | inegol
# Processing Record 37 of Set 4 | bahia honda
# Processing Record 38 of Set 4 | boa vista
# Processing Record 39 of Set 4 | nanortalik
# Processing Record 40 of Set 4 | aklavik
# Processing Record 41 of Set 4 | buala
# Processing Record 42 of Set 4 | plettenberg bay
# Processing Record 43 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 4 | sebeta
# Processing Record 45 of Set 4 | la ronge
# Processing Record 46 of Set 4 | san carlos de bariloche
# Processing Record 47 of Set 4 | southbridge
# Processing Record 48 of Set 4 | chaiya
# Processing Record 49 of Set 4 | talara
# Processing Record 50 of Set 4 | dongsheng
# Processing Record 1 of Set 5 | provideniya
# Processing Record 2 of Set 5 | sitka
# Processing Record 3 of Set 5 | karia
# Processing Record 4 of Set 5 | husavik
# Processing Record 5 of Set 5 | phan thiet
# Processing Record 6 of Set 5 | jizan
# Processing Record 7 of Set 5 | lebu
# Processing Record 8 of Set 5 | bridlington
# Processing Record 9 of Set 5 | vardo
# Processing Record 10 of Set 5 | sardarshahr
# Processing Record 11 of Set 5 | dicabisagan
# Processing Record 12 of Set 5 | constitucion
# Processing Record 13 of Set 5 | saint-augustin
# Processing Record 14 of Set 5 | talawdi
# City not found. Skipping...
# Processing Record 15 of Set 5 | hualmay
# Processing Record 16 of Set 5 | naze
# Processing Record 17 of Set 5 | katangli
# Processing Record 18 of Set 5 | yellowknife
# Processing Record 19 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 5 | batemans bay
# Processing Record 21 of Set 5 | ancud
# Processing Record 22 of Set 5 | walvis bay
# Processing Record 23 of Set 5 | dire
# Processing Record 24 of Set 5 | kulim
# Processing Record 25 of Set 5 | necochea
# Processing Record 26 of Set 5 | chokurdakh
# Processing Record 27 of Set 5 | oga
# Processing Record 28 of Set 5 | baft
# Processing Record 29 of Set 5 | skjervoy
# Processing Record 30 of Set 5 | banda aceh
# Processing Record 31 of Set 5 | novopokrovka
# Processing Record 32 of Set 5 | vestmannaeyjar
# Processing Record 33 of Set 5 | zilair
# Processing Record 34 of Set 5 | locri
# Processing Record 35 of Set 5 | sao joao da barra
# Processing Record 36 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 5 | bograd
# Processing Record 38 of Set 5 | san luis
# Processing Record 39 of Set 5 | luderitz
# Processing Record 40 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 5 | baillif
# Processing Record 42 of Set 5 | vuktyl
# Processing Record 43 of Set 5 | lavrentiya
# Processing Record 44 of Set 5 | santa marta
# Processing Record 45 of Set 5 | eenhana
# Processing Record 46 of Set 5 | murud
# Processing Record 47 of Set 5 | maragogi
# Processing Record 48 of Set 5 | haimen
# Processing Record 49 of Set 5 | marienburg
# Processing Record 50 of Set 5 | tommot
# Processing Record 1 of Set 6 | hithadhoo
# Processing Record 2 of Set 6 | xinqing
# Processing Record 3 of Set 6 | lowestoft
# Processing Record 4 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 5 of Set 6 | peniche
# Processing Record 6 of Set 6 | santa rosa
# Processing Record 7 of Set 6 | taoudenni
# Processing Record 8 of Set 6 | olafsvik
# Processing Record 9 of Set 6 | maceio
# Processing Record 10 of Set 6 | manono
# Processing Record 11 of Set 6 | bengkulu
# Processing Record 12 of Set 6 | beringovskiy
# Processing Record 13 of Set 6 | mehamn
# Processing Record 14 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 15 of Set 6 | nouadhibou
# Processing Record 16 of Set 6 | hervey bay
# Processing Record 17 of Set 6 | arlit
# Processing Record 18 of Set 6 | airai
# Processing Record 19 of Set 6 | shetpe
# Processing Record 20 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 6 | vila velha
# Processing Record 22 of Set 6 | sterling
# Processing Record 23 of Set 6 | atambua
# Processing Record 24 of Set 6 | araouane
# Processing Record 25 of Set 6 | severo-kurilsk
# Processing Record 26 of Set 6 | port elizabeth
# Processing Record 27 of Set 6 | raga
# Processing Record 28 of Set 6 | jiangyou
# Processing Record 29 of Set 6 | pak phanang
# Processing Record 30 of Set 6 | evanston
# Processing Record 31 of Set 6 | birao
# Processing Record 32 of Set 6 | veraval
# Processing Record 33 of Set 6 | teknaf
# Processing Record 34 of Set 6 | cairns
# Processing Record 35 of Set 6 | puerto cabello
# Processing Record 36 of Set 6 | ouesso
# Processing Record 37 of Set 6 | lagoa
# Processing Record 38 of Set 6 | kismayo
# Processing Record 39 of Set 6 | sovetskiy
# Processing Record 40 of Set 6 | goderich
# Processing Record 41 of Set 6 | manggar
# Processing Record 42 of Set 6 | bandar-e lengeh
# Processing Record 43 of Set 6 | sechura
# Processing Record 44 of Set 6 | imbituba
# Processing Record 45 of Set 6 | lebowakgomo
# Processing Record 46 of Set 6 | guangyuan
# Processing Record 47 of Set 6 | buritizeiro
# Processing Record 48 of Set 6 | myrtle beach
# Processing Record 49 of Set 6 | takapau
# Processing Record 50 of Set 6 | kavaratti
# Processing Record 1 of Set 7 | icoana
# Processing Record 2 of Set 7 | ulundi
# Processing Record 3 of Set 7 | tabou
# Processing Record 4 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 7 | lasa
# Processing Record 6 of Set 7 | port-gentil
# Processing Record 7 of Set 7 | leningradskiy
# Processing Record 8 of Set 7 | christchurch
# Processing Record 9 of Set 7 | zlatoustovsk
# City not found. Skipping...
# Processing Record 10 of Set 7 | nishihara
# Processing Record 11 of Set 7 | saint-georges
# Processing Record 12 of Set 7 | griffith
# Processing Record 13 of Set 7 | batyrevo
# Processing Record 14 of Set 7 | olga
# Processing Record 15 of Set 7 | campbell river
# Processing Record 16 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 7 | livingston
# Processing Record 18 of Set 7 | roma
# Processing Record 19 of Set 7 | elat
# Processing Record 20 of Set 7 | kanungu
# Processing Record 21 of Set 7 | vaitape
# Processing Record 22 of Set 7 | sosnovo-ozerskoye
# Processing Record 23 of Set 7 | mayumba
# Processing Record 24 of Set 7 | whitianga
# Processing Record 25 of Set 7 | lensk
# Processing Record 26 of Set 7 | polunochnoye
# Processing Record 27 of Set 7 | moron
# Processing Record 28 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 29 of Set 7 | cazaje
# City not found. Skipping...
# Processing Record 30 of Set 7 | luanda
# Processing Record 31 of Set 7 | caravelas
# Processing Record 32 of Set 7 | huarmey
# Processing Record 33 of Set 7 | nisia floresta
# Processing Record 34 of Set 7 | gazimurskiy zavod
# Processing Record 35 of Set 7 | ereymentau
# Processing Record 36 of Set 7 | chaman
# Processing Record 37 of Set 7 | havoysund
# Processing Record 38 of Set 7 | saldanha
# Processing Record 39 of Set 7 | sorland
# Processing Record 40 of Set 7 | kango
# Processing Record 41 of Set 7 | ilam
# Processing Record 42 of Set 7 | oranjestad
# Processing Record 43 of Set 7 | lucapa
# Processing Record 44 of Set 7 | oneonta
# Processing Record 45 of Set 7 | itanhem
# Processing Record 46 of Set 7 | straumen
# Processing Record 47 of Set 7 | gombe
# Processing Record 48 of Set 7 | lewisporte
# Processing Record 49 of Set 7 | chapais
# Processing Record 50 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 1 of Set 8 | khash
# Processing Record 2 of Set 8 | karaton
# Processing Record 3 of Set 8 | sabang
# Processing Record 4 of Set 8 | isfana
# Processing Record 5 of Set 8 | romitan
# Processing Record 6 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 8 | cascavel
# Processing Record 8 of Set 8 | estrela
# Processing Record 9 of Set 8 | show low
# Processing Record 10 of Set 8 | serov
# Processing Record 11 of Set 8 | manitouwadge
# Processing Record 12 of Set 8 | guiratinga
# Processing Record 13 of Set 8 | georgetown
# Processing Record 14 of Set 8 | quatre cocos
# Processing Record 15 of Set 8 | springbok
# Processing Record 16 of Set 8 | san vicente
# Processing Record 17 of Set 8 | salalah
# Processing Record 18 of Set 8 | mar del plata
# Processing Record 19 of Set 8 | katobu
# Processing Record 20 of Set 8 | babynino
# Processing Record 21 of Set 8 | koumac
# Processing Record 22 of Set 8 | hope
# Processing Record 23 of Set 8 | fortuna
# Processing Record 24 of Set 8 | stolin
# Processing Record 25 of Set 8 | nabire
# Processing Record 26 of Set 8 | padang
# Processing Record 27 of Set 8 | malpe
# Processing Record 28 of Set 8 | kenora
# Processing Record 29 of Set 8 | anadyr
# Processing Record 30 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 31 of Set 8 | cheney
# Processing Record 32 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 33 of Set 8 | mahajanga
# Processing Record 34 of Set 8 | yulara
# Processing Record 35 of Set 8 | ayan
# Processing Record 36 of Set 8 | laguna
# Processing Record 37 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 38 of Set 8 | becerril
# Processing Record 39 of Set 8 | yantzaza
# Processing Record 40 of Set 8 | grenaa
# Processing Record 41 of Set 8 | sept-iles
# Processing Record 42 of Set 8 | pontianak
# Processing Record 43 of Set 8 | maryville
# Processing Record 44 of Set 8 | lata
# Processing Record 45 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 8 | valle de allende
# Processing Record 47 of Set 8 | ratodero
# Processing Record 48 of Set 8 | coihaique
# Processing Record 49 of Set 8 | santa cruz de tenerife
# Processing Record 50 of Set 8 | curup
# Processing Record 1 of Set 9 | san pedro
# Processing Record 2 of Set 9 | santa catarina de tepehuanes
# Processing Record 3 of Set 9 | tessalit
# Processing Record 4 of Set 9 | flin flon
# Processing Record 5 of Set 9 | velikiy ustyug
# Processing Record 6 of Set 9 | clive
# Processing Record 7 of Set 9 | springfield
# Processing Record 8 of Set 9 | severnoye
# Processing Record 9 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 9 | uga
# Processing Record 11 of Set 9 | mount pleasant
# Processing Record 12 of Set 9 | port blair
# Processing Record 13 of Set 9 | rundu
# Processing Record 14 of Set 9 | skaerbaek
# Processing Record 15 of Set 9 | trabzon
# Processing Record 16 of Set 9 | luena
# Processing Record 17 of Set 9 | ulladulla
# Processing Record 18 of Set 9 | okhotsk
# Processing Record 19 of Set 9 | nikolayevka
# Processing Record 20 of Set 9 | bandar
# Processing Record 21 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 9 | isiro
# Processing Record 23 of Set 9 | longyearbyen
# Processing Record 24 of Set 9 | san policarpo
# Processing Record 25 of Set 9 | babushkin
# Processing Record 26 of Set 9 | codrington
# Processing Record 27 of Set 9 | saint anthony
# Processing Record 28 of Set 9 | aginskoye
# Processing Record 29 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 9 | canatlan
# Processing Record 31 of Set 9 | marrakesh
# Processing Record 32 of Set 9 | hamilton
# Processing Record 33 of Set 9 | inta
# Processing Record 34 of Set 9 | kodumudi
# Processing Record 35 of Set 9 | krizevci
# Processing Record 36 of Set 9 | saint-francois
# Processing Record 37 of Set 9 | umm lajj
# Processing Record 38 of Set 9 | smithers
# Processing Record 39 of Set 9 | muzquiz
# City not found. Skipping...
# Processing Record 40 of Set 9 | virginia beach
# Processing Record 41 of Set 9 | shubarshi
# Processing Record 42 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 43 of Set 9 | komsomolskiy
# Processing Record 44 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 9 | tuensang
# Processing Record 46 of Set 9 | bathsheba
# Processing Record 47 of Set 9 | mondovi
# Processing Record 48 of Set 9 | tuatapere
# Processing Record 49 of Set 9 | kpandae
# Processing Record 50 of Set 9 | orangeburg
# Processing Record 1 of Set 10 | nyurba
# Processing Record 2 of Set 10 | hazorasp
# Processing Record 3 of Set 10 | praia da vitoria
# Processing Record 4 of Set 10 | acari
# Processing Record 5 of Set 10 | altay
# Processing Record 6 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 7 of Set 10 | la baule-escoublac
# Processing Record 8 of Set 10 | nhulunbuy
# Processing Record 9 of Set 10 | belaya gora
# Processing Record 10 of Set 10 | borba
# Processing Record 11 of Set 10 | geraldton
# Processing Record 12 of Set 10 | storsteinnes
# Processing Record 13 of Set 10 | axim
# Processing Record 14 of Set 10 | eureka
# Processing Record 15 of Set 10 | wadena
# Processing Record 16 of Set 10 | canon city
# Processing Record 17 of Set 10 | atbasar
# Processing Record 18 of Set 10 | ucluelet
# Processing Record 19 of Set 10 | kupang
# Processing Record 20 of Set 10 | kamenka
# Processing Record 21 of Set 10 | cabedelo
# Processing Record 22 of Set 10 | chicama
# Processing Record 23 of Set 10 | brae
# Processing Record 24 of Set 10 | montepuez
# Processing Record 25 of Set 10 | gazni
# City not found. Skipping...
# Processing Record 26 of Set 10 | great yarmouth
# Processing Record 27 of Set 10 | isangel
# Processing Record 28 of Set 10 | gladstone
# Processing Record 29 of Set 10 | veshenskaya
# Processing Record 30 of Set 10 | henzada
# City not found. Skipping...
# Processing Record 31 of Set 10 | kuah
# Processing Record 32 of Set 10 | sarahan
# Processing Record 33 of Set 10 | zhovtneve
# Processing Record 34 of Set 10 | russell
# Processing Record 35 of Set 10 | cururupu
# Processing Record 36 of Set 10 | santa vitoria do palmar
# Processing Record 37 of Set 10 | vanersborg
# Processing Record 38 of Set 10 | manhattan
# Processing Record 39 of Set 10 | antofagasta
# Processing Record 40 of Set 10 | la paz
# Processing Record 41 of Set 10 | te anau
# Processing Record 42 of Set 10 | ugoofaaru
# Processing Record 43 of Set 10 | raudeberg
# Processing Record 44 of Set 10 | northam
# Processing Record 45 of Set 10 | oussouye
# Processing Record 46 of Set 10 | sipe sipe
# Processing Record 47 of Set 10 | ratnapura
# Processing Record 48 of Set 10 | zemlyansk
# Processing Record 49 of Set 10 | dharangaon
# Processing Record 50 of Set 10 | namatanai
# Processing Record 1 of Set 11 | gigmoto
# Processing Record 2 of Set 11 | maniitsoq
# Processing Record 3 of Set 11 | kayerkan
# Processing Record 4 of Set 11 | stephenville
# Processing Record 5 of Set 11 | jalpan
# Processing Record 6 of Set 11 | uglekamensk
# Processing Record 7 of Set 11 | pangai
# Processing Record 8 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 11 | zeya
# Processing Record 10 of Set 11 | svetlogorsk
# Processing Record 11 of Set 11 | faya
# Processing Record 12 of Set 11 | hohhot
# Processing Record 13 of Set 11 | fort nelson
# Processing Record 14 of Set 11 | biharkeresztes
# Processing Record 15 of Set 11 | mattru
# Processing Record 16 of Set 11 | sawai madhopur
# Processing Record 17 of Set 11 | bundaberg
# Processing Record 18 of Set 11 | malartic
# Processing Record 19 of Set 11 | comodoro rivadavia
# Processing Record 20 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 21 of Set 11 | trelaze
# Processing Record 22 of Set 11 | hinton
# Processing Record 23 of Set 11 | bulgan
# Processing Record 24 of Set 11 | buckeye
# Processing Record 25 of Set 11 | dharchula
# Processing Record 26 of Set 11 | hofn
# Processing Record 27 of Set 11 | ashtian
# Processing Record 28 of Set 11 | luau
# Processing Record 29 of Set 11 | fairbanks
# Processing Record 30 of Set 11 | qinhuangdao
# Processing Record 31 of Set 11 | toftir
# City not found. Skipping...
# Processing Record 32 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 33 of Set 11 | mount gambier
# Processing Record 34 of Set 11 | malanville
# Processing Record 35 of Set 11 | makakilo city
# Processing Record 36 of Set 11 | ostrovnoy
# Processing Record 37 of Set 11 | sao jose da coroa grande
# Processing Record 38 of Set 11 | nuuk
# Processing Record 39 of Set 11 | caceres
# Processing Record 40 of Set 11 | nanzhang
# Processing Record 41 of Set 11 | saryozek
# Processing Record 42 of Set 11 | algiers
# Processing Record 43 of Set 11 | luganville
# Processing Record 44 of Set 11 | kasongo-lunda
# Processing Record 45 of Set 11 | monrovia
# Processing Record 46 of Set 11 | sisimiut
# Processing Record 47 of Set 11 | inyonga
# Processing Record 48 of Set 11 | prince rupert
# Processing Record 49 of Set 11 | khovu-aksy
# Processing Record 50 of Set 11 | chernyshevskiy
# Processing Record 1 of Set 12 | gaimersheim
# Processing Record 2 of Set 12 | ilulissat
# Processing Record 3 of Set 12 | suleja
# Processing Record 4 of Set 12 | pukhrayan
# Processing Record 5 of Set 12 | fougamou
# Processing Record 6 of Set 12 | borujan
# City not found. Skipping...
# Processing Record 7 of Set 12 | tual
# Processing Record 8 of Set 12 | kaeo
# Processing Record 9 of Set 12 | ararat
# Processing Record 10 of Set 12 | varia
# Processing Record 11 of Set 12 | mount isa
# Processing Record 12 of Set 12 | suntar
# Processing Record 13 of Set 12 | junagadh
# Processing Record 14 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 15 of Set 12 | jaffna
# Processing Record 16 of Set 12 | tchaourou
# Processing Record 17 of Set 12 | grindavik
# Processing Record 18 of Set 12 | batagay-alyta
# Processing Record 19 of Set 12 | ketchikan
# Processing Record 20 of Set 12 | moose factory
# Processing Record 21 of Set 12 | vytegra
# Processing Record 22 of Set 12 | chornobay
# Processing Record 23 of Set 12 | sola
# Processing Record 24 of Set 12 | quebo
# Processing Record 25 of Set 12 | riberalta
# Processing Record 26 of Set 12 | itarema
# Processing Record 27 of Set 12 | evensk
# Processing Record 28 of Set 12 | esil
# Processing Record 29 of Set 12 | dunyapur
# Processing Record 30 of Set 12 | gimli
# Processing Record 31 of Set 12 | gilbues
# Processing Record 32 of Set 12 | marystown
# Processing Record 33 of Set 12 | vila
# Processing Record 34 of Set 12 | panuco
# Processing Record 35 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 36 of Set 12 | japura
# Processing Record 37 of Set 12 | owo
# Processing Record 38 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 12 | tautira
# Processing Record 40 of Set 12 | jalu
# Processing Record 41 of Set 12 | marawi
# Processing Record 42 of Set 12 | tynda
# Processing Record 43 of Set 12 | beyneu
# Processing Record 44 of Set 12 | nanakuli
# Processing Record 45 of Set 12 | vestbygda
# City not found. Skipping...
# Processing Record 46 of Set 12 | churachandpur
# Processing Record 47 of Set 12 | santa luzia
# Processing Record 48 of Set 12 | jieshi
# Processing Record 49 of Set 12 | de-kastri
# Processing Record 50 of Set 12 | bo rai
# Processing Record 1 of Set 13 | falkoping
# City not found. Skipping...
# Processing Record 2 of Set 13 | kangaatsiaq
# Processing Record 3 of Set 13 | mwandiga
# Processing Record 4 of Set 13 | voh
# Processing Record 5 of Set 13 | ruteng
# Processing Record 6 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 13 | richards bay
# Processing Record 8 of Set 13 | santa isabel do rio negro
# Processing Record 9 of Set 13 | tibati
# Processing Record 10 of Set 13 | sartell
# Processing Record 11 of Set 13 | pasighat
# Processing Record 12 of Set 13 | aksarka
# Processing Record 13 of Set 13 | bani walid
# Processing Record 14 of Set 13 | sistranda
# Processing Record 15 of Set 13 | launceston
# Processing Record 16 of Set 13 | belmonte
# Processing Record 17 of Set 13 | marv dasht
# City not found. Skipping...
# Processing Record 18 of Set 13 | tepalcatepec
# Processing Record 19 of Set 13 | taikang
# Processing Record 20 of Set 13 | muros
# Processing Record 21 of Set 13 | kloulklubed
# Processing Record 22 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 13 | ajdabiya
# Processing Record 24 of Set 13 | menongue
# Processing Record 25 of Set 13 | nsanje
# Processing Record 26 of Set 13 | katsina
# Processing Record 27 of Set 13 | balkhash
# Processing Record 28 of Set 13 | lenti
# Processing Record 29 of Set 13 | keningau
# Processing Record 30 of Set 13 | dengzhou
# Processing Record 31 of Set 13 | sasovo
# Processing Record 32 of Set 13 | martapura
# Processing Record 33 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 34 of Set 13 | turukhansk
# Processing Record 35 of Set 13 | polyarnyye zori
# Processing Record 36 of Set 13 | natchitoches
# Processing Record 37 of Set 13 | talcahuano
# Processing Record 38 of Set 13 | changji
# Processing Record 39 of Set 13 | akdepe
# Processing Record 40 of Set 13 | harunabad
# Processing Record 41 of Set 13 | havelock
# Processing Record 42 of Set 13 | viksoyri
# City not found. Skipping...
# Processing Record 43 of Set 13 | baijiantan
# Processing Record 44 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 45 of Set 13 | diego de almagro
# Processing Record 46 of Set 13 | fukagawa
# Processing Record 47 of Set 13 | vila franca do campo
# Processing Record 48 of Set 13 | kukurecani
# Processing Record 49 of Set 13 | samoylovka
# Processing Record 50 of Set 13 | thinadhoo
# Processing Record 1 of Set 14 | san rafael
# Processing Record 2 of Set 14 | baykit
# Processing Record 3 of Set 14 | iquitos
# Processing Record 4 of Set 14 | tecoanapa
# Processing Record 5 of Set 14 | saint-joseph
# Processing Record 6 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 7 of Set 14 | manaure
# Processing Record 8 of Set 14 | alihe
# Processing Record 9 of Set 14 | villarrica
# Processing Record 10 of Set 14 | vao
# Processing Record 11 of Set 14 | hambantota
# Processing Record 12 of Set 14 | robertsport
# Processing Record 13 of Set 14 | prado
# Processing Record 14 of Set 14 | portland
# Processing Record 15 of Set 14 | vestmanna
# Processing Record 16 of Set 14 | prieska
# Processing Record 17 of Set 14 | acara
# Processing Record 18 of Set 14 | mamallapuram
# Processing Record 19 of Set 14 | reconquista
# Processing Record 20 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 14 | kazuno
# Processing Record 22 of Set 14 | fort-shevchenko
# Processing Record 23 of Set 14 | ryazhsk
# Processing Record 24 of Set 14 | coahuayana
# Processing Record 25 of Set 14 | pilar
# Processing Record 26 of Set 14 | tromso
# Processing Record 27 of Set 14 | kargil
# Processing Record 28 of Set 14 | caxito
# Processing Record 29 of Set 14 | itaituba
# Processing Record 30 of Set 14 | xai-xai
# Processing Record 31 of Set 14 | mandurah
# Processing Record 32 of Set 14 | baruun-urt
# Processing Record 33 of Set 14 | omboue
# Processing Record 34 of Set 14 | baoning
# Processing Record 35 of Set 14 | morgan city
# Processing Record 36 of Set 14 | benguela
# Processing Record 37 of Set 14 | merauke
# Processing Record 38 of Set 14 | bilma
# Processing Record 39 of Set 14 | canakkale
# Processing Record 40 of Set 14 | palora
# Processing Record 41 of Set 14 | chihuahua
# Processing Record 42 of Set 14 | khilok
# Processing Record 43 of Set 14 | jaipur hat
# City not found. Skipping...
# Processing Record 44 of Set 14 | ouro preto do oeste
# Processing Record 45 of Set 14 | brainerd
# Processing Record 46 of Set 14 | mecca
# Processing Record 47 of Set 14 | sinnamary
# Processing Record 48 of Set 14 | banfora
# Processing Record 49 of Set 14 | meulaboh
# Processing Record 50 of Set 14 | sioux city
# Processing Record 1 of Set 15 | saint-pierre
# Processing Record 2 of Set 15 | nalut
# Processing Record 3 of Set 15 | jacareacanga
# Processing Record 4 of Set 15 | agadir
# Processing Record 5 of Set 15 | vereeniging
# Processing Record 6 of Set 15 | katha
# City not found. Skipping...
# Processing Record 7 of Set 15 | sorong
# Processing Record 8 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 15 | marsh harbour
# Processing Record 10 of Set 15 | yerbogachen
# Processing Record 11 of Set 15 | tsilna
# Processing Record 12 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 13 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 14 of Set 15 | tokur
# Processing Record 15 of Set 15 | giyani
# Processing Record 16 of Set 15 | ust-nera
# Processing Record 17 of Set 15 | the valley
# Processing Record 18 of Set 15 | strezhevoy
# Processing Record 19 of Set 15 | tonj
# Processing Record 20 of Set 15 | kysyl-syr
# Processing Record 21 of Set 15 | miandrivazo
# Processing Record 22 of Set 15 | nome
# Processing Record 23 of Set 15 | zhangye
# Processing Record 24 of Set 15 | cockburn town
# Processing Record 25 of Set 15 | san ramon
# Processing Record 26 of Set 15 | nantucket
# Processing Record 27 of Set 15 | hobyo
# Processing Record 28 of Set 15 | deputatskiy
# Processing Record 29 of Set 15 | arroio grande
# Processing Record 30 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 31 of Set 15 | karratha
# Processing Record 32 of Set 15 | diffa
# Processing Record 33 of Set 15 | zyryanovsk
# Processing Record 34 of Set 15 | sao filipe
# Processing Record 35 of Set 15 | iralaya
# Processing Record 36 of Set 15 | lagunas
# Processing Record 37 of Set 15 | kresttsy
# Processing Record 38 of Set 15 | baudh
# Processing Record 39 of Set 15 | ilhabela
# Processing Record 40 of Set 15 | cayenne
# Processing Record 41 of Set 15 | hoquiam
# Processing Record 42 of Set 15 | rocha
# Processing Record 43 of Set 15 | beyla
# Processing Record 44 of Set 15 | socorro
# Processing Record 45 of Set 15 | kushima
# Processing Record 46 of Set 15 | pakxan
# Processing Record 47 of Set 15 | teruel
# Processing Record 48 of Set 15 | okolona
# Processing Record 49 of Set 15 | rongcheng
# Processing Record 50 of Set 15 | novyye burasy
# Processing Record 1 of Set 16 | inirida
# Processing Record 2 of Set 16 | minas de barroteran
# Processing Record 3 of Set 16 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 16 | pangnirtung
# Processing Record 5 of Set 16 | palembang
# Processing Record 6 of Set 16 | port augusta
# Processing Record 7 of Set 16 | ternate
# Processing Record 8 of Set 16 | inzhavino
# Processing Record 9 of Set 16 | mareeba
# Processing Record 10 of Set 16 | nangomba
# Processing Record 11 of Set 16 | emerald
# Processing Record 12 of Set 16 | tabas
# Processing Record 13 of Set 16 | yumen
# Processing Record 14 of Set 16 | temiscaming
# Processing Record 15 of Set 16 | camacha
# Processing Record 16 of Set 16 | ascension
# Processing Record 17 of Set 16 | kudat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 703

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea      PF -23.1203 -134.9692     77.20        65          31
# 1    Nikolskoye      RU  59.7035   30.7861     37.87        54         100
# 2         Atasu      KZ  48.6814   71.6433     55.62        40          98
# 3     Stoughton      US  42.1251  -71.1023     52.56        36          89
# 4         Manta      EC  -0.9500  -80.7333     82.18        74          40
# 5     Saskylakh      RU  71.9167  114.0833     24.46        93         100
# 6       Qaanaaq      GL  77.4840  -69.3632     29.82        95         100
# 7       Ushuaia      AR -54.8000  -68.3000     40.66        60          40
# 8       Iqaluit      CA  63.7506  -68.5145     13.73        56          75
# 9  Kruisfontein      ZA -34.0033   24.7314     57.87        62          12
#
#    Wind Speed Current Description
# 0       20.31    scattered clouds
# 1        7.65     overcast clouds
# 2        7.90     overcast clouds
# 3        7.00     overcast clouds
# 4        5.75    scattered clouds
# 5       10.29     overcast clouds
# 6        3.96                snow
# 7       26.46    scattered clouds
# 8        8.05       broken clouds
# 9        2.42          few clouds

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
